# %% [markdown]
# # Projeto Prático

# %% [markdown]
# Este projeto prático é uma atividade proposta no capítulo 3 sobre análise
# no processo de destilação fracionada de petróleo.

# %%
#!pip install neupy

# %%
import pandas as pd
from neupy import algorithms
# Out:
# /home/rafael/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/rafael/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/rafael/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
amostra = pd.read_excel("/home/rafael/git/book_artificial_neural_network/materiais/MateriaisCapítulo03_RNA/Tabela#3.3_RNA.xls")
train = pd.read_excel("/home/rafael/git/book_artificial_neural_network/materiais/MateriaisApêndiceI_RNA/Tabela#SeÆo3.6_RNA.xls")

# %%
train
# Out:
#         x1      x2       x3  d
# 0  -0.6508  0.1097   4.0009 -1
# 1  -1.4492  0.8896   4.4005 -1
# 2   2.0850  0.6876  12.0710 -1
# 3   0.2626  1.1476   7.7985  1
# 4   0.6418  1.0234   7.0427  1
# 5   0.2569  0.6730   8.3265 -1
# 6   1.1155  0.6043   7.4446  1
# 7   0.0914  0.3399   7.0677 -1
# 8   0.0121  0.5256   4.6316  1
# 9  -0.0429  0.4660   5.4323  1
# 10  0.4340  0.6870   8.2287 -1
# 11  0.2735  1.0287   7.1934  1
# 12  0.4839  0.4851   7.4850 -1
# 13  0.4089 -0.1267   5.5019 -1
# 14  1.4391  0.1614   8.5843 -1
# 15 -0.9115 -0.1973   2.1962 -1
# 16  0.3654  1.0475   7.4858  1
# 17  0.2144  0.7515   7.1699  1
# 18  0.2013  1.0014   6.5489  1
# 19  0.6483  0.2183   5.8991  1
# 20 -0.1147  0.2242   7.2435 -1
# 21 -0.7970  0.8795   3.8762  1
# 22 -1.0625  0.6366   2.4707  1
# 23  0.5307  0.1285   5.6883  1
# 24 -1.2200  0.7777   1.7252  1
# 25  0.3957  0.1076   5.6623 -1
# 26 -0.1013  0.5989   7.1812 -1
# 27  2.4482  0.9455  11.2095  1
# 28  2.0149  0.6192  10.9263 -1
# ...

# %%
hebbnet = algorithms.HebbRule()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-b9daff544903> in <module>
# ----> 1 hebbnet = algorithms.HebbRule()
#
# ~/anaconda3/lib/python3.7/site-packages/neupy/algorithms/associative/base.py in __init__(self, **options)
#      43
#      44     def __init__(self, **options):
# ---> 45         super(BaseAssociative, self).__init__(**options)
#      46         self.init_weights()
#      47
#
# ~/anaconda3/lib/python3.7/site-packages/neupy/algorithms/base.py in __init__(self, *args, **options)
#     174
#     175     def __init__(self, *args, **options):
# --> 176         super(BaseNetwork, self).__init__(*args, **options)
#     177
#     178         self.last_epoch = 0
#
# ~/anaconda3/lib/python3.7/site-packages/neupy/algorithms/base.py in __init__(self, *args, **options)
#      47
#      48     def __init__(self, *args, **options):
# ...

# %%
hebbnet.train(train, epochs=2)

# %%
hebbnet.predict(amostra)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-5491dcf9dbca> in <module>
# ----> 1 hebbnet.predict(amostra)
#
# ~/anaconda3/lib/python3.7/site-packages/neupy/algorithms/associative/base.py in predict(self, X)
#     147     def predict(self, X):
#     148         X = format_data(X, is_feature1d=False)
# --> 149         raw_output = X.dot(self.weight) + self.bias
#     150         return np.where(raw_output > 0, 1, 0)
#     151
#
# ValueError: shapes (10,3) and (4,1) not aligned: 3 (dim 1) != 4 (dim 0)

# %%
amostra
# Out:
#        x1      x2      x3
# 0 -0.3665  0.0620  5.9891
# 1 -0.7842  1.1267  5.5912
# 2  0.3012  0.5611  5.8234
# 3  0.7757  1.0648  8.0677
# 4  0.1570  0.8028  6.3040
# 5 -0.7014  1.0316  3.6005
# 6  0.3748  0.1536  6.1537
# 7 -0.6920  0.9404  4.4058
# 8 -1.3970  0.7141  4.9263
# 9 -1.8842 -0.2805  1.2548
